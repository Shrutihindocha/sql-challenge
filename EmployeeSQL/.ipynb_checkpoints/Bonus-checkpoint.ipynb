# %%
# Dependencies
# ----------------------------------
from sqlalchemy import create_engine
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Create engines
engine = create_engine('postgresql://postgres:postgres@localhost:5432/sql-challenge')
# Out:
# /Users/shrutihindocha/anaconda3/envs/PythonData/lib/python3.7/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#Creating dfs for salaries, titles and employees

salaries_df = pd.read_sql("SELECT * FROM salaries", engine)
#salaries_df
titles_df = pd.read_sql("SELECT * FROM titles", engine)
# titles_df
employees_df = pd.read_sql("SELECT * FROM employees", engine)
#employees_df

# %%
#Renaming title_id to emp_title_id

titles_df = titles_df.rename(columns={'title_id': 'emp_title_id'})

titles_df
# Out:
#   emp_title_id               title
# 0        s0001               Staff
# 1        s0002        Senior Staff
# 2        e0001  Assistant Engineer
# 3        e0002            Engineer
# 4        e0003     Senior Engineer
# 5        e0004    Technique Leader
# 6        m0001             Manager

# %%
#merging salaries and title IDs into the employees table 
merged_df = employees_df.merge(salaries_df, on="emp_no", how="inner")

merged_df = merged_df.merge(titles_df, on="emp_title_id", how = "inner")

merged_df
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001  1953-07-25    Hideyuki    Zallocco   M
# 1       421786        s0001  1957-09-28       Xiong    Verhoeff   M
# 2       273487        s0001  1957-04-14   Christoph     Parfitt   M
# 3       246449        s0001  1958-03-23       Subbu  Bultermann   F
# 4        48085        s0001  1964-01-19  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 300019  111400        m0001  1959-11-09        Arie     Staelin   M
# 300020  111133        m0001  1955-03-16       Hauke       Zhang   M
# 300021  110085        m0001  1959-10-28        Ebru       Alpin   M
# 300022  110386        m0001  1953-10-04        Shem      Kieras   M
# 300023  111784        m0001  1956-06-14       Marjo  Giarratana   F
#
#          hire_date  salary    title
# 0       1990-04-28   40000    Staff
# 1       1987-11-26   40000    Staff
# 2       1991-06-28   56087    Staff
# ...

# %%
#group by title

title_salary_df = merged_df.groupby("title").mean()["salary"]

title_salary_df = title_salary_df.reset_index()

title_salary_df
# Out:
#                 title        salary
# 0  Assistant Engineer  48564.434447
# 1            Engineer  48535.336511
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.799871
# 4        Senior Staff  58550.172704
# 5               Staff  58465.382850
# 6    Technique Leader  48582.896092

# %%
#plotting bar chart for salaries by title
x_axis = title_salary_df["title"]
y_axis = title_salary_df["salary"]

plt.xticks(rotation=90)
plt.bar(x_axis, y_axis, color="b", align="center")
# Out:
# <BarContainer object of 7 artists>
